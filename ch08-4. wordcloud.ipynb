# %% [markdown]
# # 워드 클라우드

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
mpl.rc('font', family='Malgun Gothic')
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 14

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %% [markdown]
# # Alice in Wonderland

# %%
text = open('data/wc1.alice.txt').read()
alice_mask = np.array(Image.open('data/wc2.alice_mask.png'))

stopwords = set(STOPWORDS)
stopwords.add("said")

# %%
alice_mask2 = np.array(Image.open('data/wc5.heart.jpg'))

# %%
len(STOPWORDS)
# Out:
# 192

# %%
STOPWORDS[:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b919c25059ab> in <module>
# ----> 1 STOPWORDS[:10]
#
# TypeError: 'set' object is not subscriptable

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
len(stopwords)
# Out:
# 193

# %%
plt.figure(figsize=(12,12))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text_ = [word for word in text.split() if word.lower() not in stopwords]
text = ' '.join([str(elem) for elem in text_])

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_mask2, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask)
wc = wc.generate(text)
wc.words_
# Out:
# {'Luke': 1.0,
#  'Han': 0.46095238095238095,
#  'DEATH STAR': 0.4266666666666667,
#  'THREEPIO': 0.4,
#  'Ben': 0.2914285714285714,
#  'ship': 0.21523809523809523,
#  'Leia': 0.2019047619047619,
#  'one': 0.18285714285714286,
#  'Artoo': 0.17333333333333334,
#  'look': 0.16952380952380952,
#  'RED LEADER': 0.16952380952380952,
#  'back': 0.15619047619047619,
#  'going': 0.13904761904761906,
#  'two': 0.13142857142857142,
#  'Biggs': 0.13142857142857142,
#  'move': 0.13142857142857142,
#  'INT DEATH': 0.1295238095238095,
#  'TIE fighter': 0.1295238095238095,
#  'EXT SPACE': 0.12761904761904763,
#  'Vader': 0.12571428571428572,
#  'see': 0.1219047619047619,
#  'MILLENNIUM FALCON': 0.1219047619047619,
#  'right': 0.1180952380952381,
#  'Luke WING': 0.1180952380952381,
#  'trooper': 0.11428571428571428,
#  'robot': 0.10857142857142857,
#  'small': 0.10666666666666667,
#  'toward': 0.10476190476190476,
#  'now': 0.09904761904761905,
#  'WING FIGHTER': 0.09904761904761905,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc2 = WordCloud(background_color='white', max_words=2000, mask=alice_mask2,
              stopwords = stopwords)
wc2 = wc2.generate(text)
wc2.words_
# Out:
# {'Alice': 1.0,
#  'little': 0.29508196721311475,
#  'one': 0.25956284153005466,
#  'know': 0.2459016393442623,
#  'thing': 0.2185792349726776,
#  'time': 0.2103825136612022,
#  'Queen': 0.20765027322404372,
#  'see': 0.1830601092896175,
#  'King': 0.17486338797814208,
#  'now': 0.16393442622950818,
#  'went': 0.15846994535519127,
#  'began': 0.15846994535519127,
#  'way': 0.1557377049180328,
#  'Hatter': 0.1557377049180328,
#  'Mock Turtle': 0.15300546448087432,
#  'say': 0.15027322404371585,
#  'Gryphon': 0.15027322404371585,
#  'well': 0.14754098360655737,
#  'think': 0.1448087431693989,
#  'quite': 0.14207650273224043,
#  'much': 0.13934426229508196,
#  'first': 0.13934426229508196,
#  'thought': 0.1366120218579235,
#  'go': 0.1366120218579235,
#  'head': 0.13114754098360656,
#  'What': 0.13114754098360656,
#  'never': 0.1284153005464481,
#  'voice': 0.12568306010928962,
#  'looked': 0.12295081967213115,
#  'got': 0.12295081967213115,
#  'must': 0.12021857923497267,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Star Wars - A new hope

# %%
text = open('data/wc3.a_new_hope.txt').read()

text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('data/wc4. stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add("int")
stopwords.add("ext")

# %%
text_ = [word for word in text.split() if word.lower() not in stopwords]
text = ' '.join([str(elem) for elem in text_])

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'ext',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'int',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
# ...

# %%
wc = WordCloud(max_words=1000, mask=mask, margin=10, random_state=1).generate(text)

default_colors = wc.to_array()

# %%
# HSL : 색조(hue), 포화(saturation), 밝기(lightness)
import random
def grey_color_func(word, font_size, position, orientation, 
                    random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)

# %%
s = 'hsl(0, 0%%, %d%%)' % random.randint(60,100)
s
# Out:
# 'hsl(0, 0%, 72%)'

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3),
          interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 여자친구 선물 고르기

# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %%
html_ = 'https://kin.naver.com/search/list.nhn?'
html = html_ + 'query={key_word}&page={num}'

response = urlopen(html.format(num=1, key_word=urllib.parse.quote('여친 선물')))
soup = BeautifulSoup(response, "html.parser")
dl_ = soup.find_all('dl')

# %%
# html_ = 'https://search.naver.com/search.naver?where=kin'
# html = html_ + '&sm=tab_jum&ie=utf8&query={key_word}&start={num}' query={key_word}&page={num}

# response = urlopen(html.format(num=1, key_word=urllib.parse.quote('여친 선물')))
# soup = BeautifulSoup(response, "html.parser")
# tmp = soup.find_all('dl')

# %%
tmp_list = []
for line in dl_:
    tmp_list.append(line.text)
    
tmp_list[:5]
# Out:
# ['\n\n천여여친 선물 추\n\n2020.06.22.\n천여여친 선물 추  저는 조금 특별한 선물 추천 드립니다 저도 흔한 선물을 다... 특별한선물 여친선물 : DAON FLOWER [DAON FLOWER] 꽃과 향을 선물하다. DAON smartstore.... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 6\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n여친선물로 뭘 줘야 할까요?\n\n2020.05.21.\n여친선물로 뭘 줘야 할까요?  안녕하세요 저는 종로3가에서 귀금속을 하고 있는 예문입니다 어떤 특별한 날인가요 그러면 특별하게 선물을 주시는 게 좋을 거 같아서요 기념이... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n아빠가 어제 카드 주셔서 여친 선물\n\n2020.02.04.\n아빠가 어제 카드 주셔서 여친 선물 사는데에 20만원 썼거든요?? 근데 여친이 또 사달라는게 있는데 그게 30만원이에요... 근데 또 돈쓰면 아빠가 뭐라 할것같고 안사주면... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
# ...

# %%
import tqdm

present_candi_text = []
for n in tqdm.notebook.tqdm(range(1, 1000, 10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('여자 친구 선물')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        line_str = line.text.replace('\t','').replace('\n','')
        present_candi_text.append(line_str)
        
    time.sleep(0.5)

# %%
with open("data/w6_present_candi.txt", "w", -1, 'utf-8') as f:
    for line in present_candi_text:
        f.write(line+'\n')

# %%
len(present_candi_text)
# Out:
# 1000

# %%
present_text = ''

for each_line in present_candi_text:
    present_text += each_line + '\n'

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
gifts = okt.nouns(present_text)
gifts[:10]
# Out:
# ['여자친구', '선물', '여자친구', '독립', '축하', '기념', '선물', '여자친구', '선물', '양해']

# %%
import nltk
gifts = nltk.Text(gifts, name='여자 친구 선물')
print(len(gifts.tokens))
print(len(set(gifts.tokens)))
# Out:
# 25797
# 705

# %%
gifts.vocab().most_common(100)
# Out:
# [('선물', 3025),
#  ('여자친구', 2952),
#  ('목걸이', 2607),
#  ('수', 2005),
#  ('추천', 1956),
#  ('답변', 1033),
#  ('때', 878),
#  ('중', 865),
#  ('용', 865),
#  ('참고', 860),
#  ('하트', 860),
#  ('다이아', 859),
#  ('티니', 859),
#  ('인기', 858),
#  ('완전', 856),
#  ('연애', 502),
#  ('결혼', 357),
#  ('고민', 305),
#  ('상담', 143),
#  ('이성', 141),
#  ('쥬니버', 125),
#  ('네이버', 120),
#  ('용법', 120),
#  ('가족', 97),
#  ('이벤트', 97),
#  ('행사', 94),
#  ('고', 75),
#  ('초', 74),
#  ('중학생', 74),
#  ('내공', 71),
#  ('문구', 67),
#  ('만년필', 65),
#  ('미술', 65),
#  ('용품', 65),
#  ('좀', 46),
#  ('제', 41),
#  ('화장품', 34),
#  ('뭐', 33),
#  ('생각', 27),
#  ('여자', 23),
#  ('생일', 22),
#  ('지갑', 22),
#  ('화이트데이', 21),
#  ('걸', 20),
#  ('요', 20),
#  ('저', 19),
#  ('향수', 17),
#  ('것', 16),
#  ('가격', 16),
#  ('크리스마스', 16),
#  ('거', 15),
#  ('이번', 15),
#  ('커플', 14),
#  ('로', 13),
#  ('질문', 13),
#  ('뭘', 12),
#  ('게', 11),
#  ('꽃', 11),
#  ('반지', 11),
#  ('감동', 10),
#  ('가방', 10),
#  ('살', 10),
#  ('쇼핑', 10),
#  ('브랜드', 9),
# ...

# %%
# print(set(gifts.tokens))
sw_text = ' '.join([str(elem) for elem in set(gifts.tokens)])
print(sw_text)
# Out:
# 피 통화 다담 목도리 무협 루이비통 곧 만년필 로션 처음 사업자 손편지 리얼 정말 확인 제외 애 치가 독립 원데이 실용 게이 서여 속옷 디자인 먼저 안 여름 링 섬유 지방선거 지식인 메모리 티 쥬얼리 후 인형 이어폰 수 그동안 크림 용인 여자 벨트 군대 데이트 여성 음식 주년 초콜릿 예상 상자 편지 오세아니아 분 초반 에스티 폭시 치 부모님 고생 펜던트 덕후 탈취 마리오 자 센스 실버 무엇 스카프 둿 우선 네 날씨 초등학생 완전 근방 제품 갤럭시 장미꽃 생각 라면 얼마 장미 드림 글구 뒤 용 막상 비 이 인기 구류 손바닥 가죽 선물 사이트 수제 따뚜아쥬 광장 이성 머그컵 주위 주문 확행 베스트 톤 택배 재료 해주 빨강 포토 향수 가게 셜 음향 재회 쭈니 초콜렛 더 철 달 가요 텀블러 티니 피부 종합 양산 박 살 오즈 발찌 티셔츠 잉크 저녁 점점 초등학교 무스 벌써 제대로 사서 꼭 저번 생활 준 쪽 추억 암거 존경 워터 세럼 발렌타인 향기 파운데이션 인터넷 마우스패드 잡고 메세지 양해 샤넬 전 가지 괜찬을듯해 진주 카메라 모두 세시 만들기 거 루이까또즈 며칠 채팅 요 아이템 옷 점 네이션 금 때 회사 축하 만원 마음 목 메이커 거의 의견 부 누가 건강 시구 한지 사양 커플링 레몬 하니 리버 편도 노미 의미 폰 정해 펄찌 핸드 불가리 고수 여동생 담배 초소 스팅 움 명절 발렌타인데이 만 차라리 포에버 백화점 오렌지 부담 지갑 하여튼 자주 중학생 도대체 전자담배 군 사주면 시간 꽃집 지역 돈 일찍 가을 버스 이하 미술 말씀 고해 개 토 우편 조언 졸업 힘 정도 상담 기초 정 고 학기 작업 체형 방학 줄 테크 매일 물품 목걸이 하나 다시 음 고등학생 비타민 여러가지 고급 데 주 코튼 성인 공주 전여자친구 쇼 입생로랑 호 행동 대학입학 선 활용 려고 건조과일 이면 컬러 대비 심즈 해 진짜 청계 모바일폰 끼 중동 언니 신발 포함 내내 산물 볶음 또 밥 가기 걸 용도 관리 언제 비밀연애 대학 질문 귀걸이 톰 자몽 제격 중반 마크 셀 때문 전문 때매 이름 최근 이자 체크
# ...

# %%
sw_text = "피 통화 다담 무협 곧 처음 사업자 리얼 정말 확인 제외 애 치가 독립 원데이 실용 게이 서여 디자인 먼저 안 여름  섬유 지방선거 지식인 메모리 후 그동안 용인 여자 데이트 여성 음식 주년 예상 상자 오세아니아 분 초반 에스티 치 부모님 덕후 탈취 마리오 자 센스 무엇 둿 우선 네 날씨 초등학생 완전 근방 제품 생각 라면 얼마 장미 드림 글구 뒤 용 막상 비 이 인기 구류 손바닥 선물 사이트 수제 따뚜아쥬 광장 이성 주위 주문 확행 베스트 톤 택배 재료 해주 빨강 가게 셜 음향 재회 쭈니 더 철 달 가요 티니 피부 종합 박 살 오즈 잉크 저녁 점점 초등학교 무스 벌써 제대로 사서 꼭 저번 생활 준 쪽 추억 암거 존경 워터 향기 인터넷 잡고 메세지 양해 전 가지 괜찬을듯해 모두 세시 만들기 거 며칠 채팅 요 아이템 점 네이션 때 회사 마음 목 거의 의견 부 누가 건강 시구 한지 사양 레몬 하니 리버 편도 노미 의미  정해 펄찌 핸드 고수 여동생 초소 스팅 움 명절 발렌타인데이 만 차라리 포에버 오렌지 부담 하여튼 자주 중학생 도대체 군 사주면 시간 지역 일찍 가을 버스 이하 미술 말씀 개 토 우편 조언 졸업 힘 정도 상담 기초 정 고 학기 작업 체형 방학 줄 매일 물품 하나 다시 음 고등학생 여러가지 고급 데 주 코튼 성인 공주 전여자친구 쇼 입생로랑 호 행동 대학입학 선 활용 려고 이면 컬러 대비 심즈 해 진짜 청계 끼 중동 언니 신발 포함 내내 산물 볶음 또 밥 가기 걸 용도 관리 언제 비밀연애 대학 질문 톰 제격 중반 마크 셀 때문 전문 때매 이름 최근 이자 체크 렐라 하카 님들 지금 신경 참고 얼굴 학교생활 내공 달달 반 용품 스탠드 고등학교 공예 빼 홀로 녹음기 행사 대충 소나기 가격 요즘 경우 영양 날 그랜피 대학생 색상 위 소개 포니테일 순간 를 천연 쥬니버 떄 후반 뭐 색 대요 강남 성의 남자 준비 루나 커플 초 일단 직업 맛 가장 겸 검 이틀 해주시 기념 계절 송이 저 그냥 팟 프리저 등등 풍속 손가락 외 수수 찬 앤북 카드 벨벳 다음 거리 루 해도 코스 별로 여의 너클 호가 현재 교환학생 반나절 취미처럼 이내 그게 연락 곳 연인 오락 브드 여친 영화 은근 빼빼로데이 뭘 친구 이벤트 피어싱 성분 부다 아이디어 취업 졸업식 메트로 레이스 제일 살이 서도 기 구영 중고 미투데이 코미디 상큼 무료 류량 꿈 예비 로 오빠 함 액션 이직 괸찮치만 하루 글 펜션 하루하루 지식 말 중국 민원 로즈데이 감동 친 첫 최고 한민 대면 래서 오늘 중지 무난 용법 전역 병영 기분 초딩 길찾기 학년 데이 등 팩트 계획 한번 후드 남성 건즈더듀얼 미리 마디 피스 은행 그것 플립 시티 중 사실 값 어쨌든 직접 다른 다음주 포장 대도 일주일 적극 의식 강추 주니 티나 김 서울 것 최대 저가 혹시 타이밍 파티 정성 나중 비비드 고민 투맨 퍼온거 욕설 인 문구 이중 번 대해 일 가족 놀이 정식 블랙 전화 사람과 부분 거도 사려 건 영상 뷰티 크게 사랑 시내 음질 적 화장 미만 안나 구 매 비스킷 저기 전후 무슨 기도 거나 광역 아래 네이버 좀 잡화 왜 겟잇뷰티 학생 연말 유얼 럼 한편 고향 답변 땜 쪼금 행정 그룹 케이스 접 가성 만화 우정 약 규어 슬 봣 항상 나이 이제 일주년 금함 그 햇빛 세트 도움 루미 머 둘 기념일 당장 겨울 동안 결과 향 살껀데 방송 친한친구 종류 문제 입문 조금 신고 크리스마스 색깔 보증 여자친구 토닥토닥 리스트 교통 영구 제 전부 원래 생일 연애 너 바 용산 연상연하 고삼 얘기 게 이요 기억 중후 스 밍 사람 홍 하트 화이트데이 크롬 추천 상품 고요 발레 동갑 이번 모델 진 부탁 애니메이션"

# %%
sw_text = '''피 통화 다담 무협 곧 처음 사업자 리얼 정말 확인 제외 애 치가 독립 원데이 실용 게이 서여 디자인 먼저 안 여름  섬유 지방선거 지식인 메모리 후 그동안 용인 여자 여성 음식 주년 예상 상자 오세아니아 분 초반 에스티 치 부모님 덕후 탈취 마리오 자 센스 무엇 둿 우선 네 날씨 초등학생 완전 근방 제품 생각 라면 얼마 장미 드림 글구 뒤 용 막상 비 이 인기 구류 손바닥 사이트 수제 따뚜아쥬 광장 이성 주위 주문 확행 베스트 톤 택배 재료 해주 빨강 가게 셜 음향 재회 쭈니 더 철 달 가요 티니 피부 종합 박 살 오즈 잉크 저녁 점점 초등학교 무스 벌써 제대로 사서 꼭 저번 생활 준 쪽 추억 암거 존경 워터 향기 인터넷 잡고 메세지 양해 전 가지 괜찬을듯해 모두 세시 만들기 거 며칠 채팅 아이템 점 네이션 때 회사 마음 목 거의 의견 부 누가 건강 시구 한지 사양 레몬 하니 리버 편도 노미 의미  정해 펄찌 핸드 고수 여동생 초소 스팅 움 명절 발렌타인데이 만 차라리 포에버 오렌지 부담 하여튼 자주 중학생 도대체 군 사주면 시간 지역 일찍 가을 버스 이하 미술 말씀 개 토 우편 조언 졸업 힘 정도 상담 기초 정 고 학기 작업 체형 방학 줄 매일 물품 하나 다시 음 고등학생 여러가지 고급 데 주 코튼 성인 공주 전여자친구 쇼 호 행동 대학입학 선 활용 려고 이면 컬러 대비 심즈 해 진짜 청계 끼 중동 언니 신발 포함 내내 산물 볶음 또 밥 가기 걸 용도 관리 언제 비밀연애 대학 질문 톰 제격 중반 마크 셀 때문 전문 때매 이름 최근 이자 체크 렐라 하카 님들 지금 신경 참고 얼굴 학교생활 내공 달달 반 용품 스탠드 고등학교 공예 빼 홀로 녹음기 행사 대충 소나기 가격 요즘 경우 영양 날 그랜피 대학생 색상 위 소개 포니테일 순간 를 천연 쥬니버 떄 후반 뭐 색 대요 강남 성의 남자 준비 루나 커플 초 일단 직업 맛 가장 겸 검 이틀 해주시 기념 계절 송이 저 그냥 팟 프리저 등등 풍속 손가락 외 수수 찬 앤북 카드 벨벳 다음 거리 루 해도 코스 별로 여의 너클 호가 현재 교환학생 반나절 취미처럼 이내 그게 연락 곳 연인 오락 브드 여친 은근 빼빼로데이 뭘 친구 이벤트 피어싱 성분 부다 아이디어 취업 졸업식 메트로 레이스 제일 살이 서도 기 구영 중고 미투데이 코미디 상큼 무료 류량 꿈 예비 로 오빠 함 액션 이직 괸찮치만 하루 글 하루하루 지식 말 중국 민원 로즈데이 감동 친 첫 최고 한민 대면 래서 오늘 중지 무난 용법 전역 병영 기분 초딩 길찾기 학년 데이 등 팩트 계획 한번 후드 남성 건즈더듀얼 미리 마디 피스 은행 그것 플립 시티 중 사실 값 어쨌든 직접 다른 다음주 포장 대도 일주일 적극 의식 강추 주니 티나 김 서울 것 최대 저가 혹시 타이밍 파티 정성 나중 비비드 고민 투맨 퍼온거 욕설 인 문구 이중 번 대해 일 가족 놀이 정식 블랙 전화 사람과 부분 거도 사려 건 영상 뷰티 크게 사랑 시내 음질 적 화장 미만 안나 구 매 비스킷 저기 전후 무슨 기도 거나 광역 아래 네이버 좀 잡화 왜 겟잇뷰티 학생 연말 유얼 럼 한편 고향 답변 땜 쪼금 행정 그룹 접 가성 만화 우정 약 규어 슬 봣 항상 나이 이제 일주년 금함 그 햇빛 세트 도움 루미 머 둘 기념일 당장 겨울 동안 결과 향 살껀데 방송 친한친구 종류 문제 입문 조금 신고 크리스마스 색깔 보증 여자친구 토닥토닥 리스트 교통 영구 제 전부 원래 생일 연애 너 바 용산 연상연하 고삼 얘기 게 이요 기억 중후 스 밍 사람 홍 화이트데이 크롬 추천 상품 고요 발레 동갑 이번 모델 진 부탁 애니메이션'''

# %%
stop_words = sw_text.split()

# %%
text_ = [gift for gift in gifts if gift not in stop_words]
# gifts.
# text = ' '.join([str(elem) for elem in text_])

# %%
gifts = nltk.Text(text_, name='여자 친구 선물')

# %%
gifts.vocab().most_common(50)
# Out:
# [('선물', 3025),
#  ('목걸이', 2607),
#  ('수', 2005),
#  ('하트', 860),
#  ('다이아', 859),
#  ('결혼', 371),
#  ('만년필', 65),
#  ('화장품', 34),
#  ('지갑', 22),
#  ('요', 20),
#  ('향수', 17),
#  ('꽃', 11),
#  ('반지', 11),
#  ('쇼핑', 11),
#  ('브랜드', 9),
#  ('가방', 9),
#  ('목도리', 9),
#  ('팔찌', 8),
#  ('귀걸이', 7),
#  ('펜던트', 6),
#  ('케이스', 6),
#  ('손편지', 6),
#  ('명품', 6),
#  ('편지', 6),
#  ('옷', 5),
#  ('초콜릿', 5),
#  ('패션', 5),
#  ('틴트', 5),
#  ('노트북', 5),
#  ('전자담배', 4),
#  ('속옷', 4),
#  ('꽃집', 4),
#  ('이어폰', 4),
#  ('루이비통', 4),
#  ('시계', 3),
#  ('다이어트', 3),
#  ('루이까또즈', 3),
#  ('벨트', 3),
#  ('넥타이', 3),
#  ('폰', 3),
#  ('가죽', 3),
#  ('발렌타인', 3),
#  ('데이트', 3),
#  ('쿠키', 2),
#  ('마카롱', 2),
#  ('취미', 2),
#  ('군대', 2),
#  ('생로랑', 2),
#  ('여행', 2),
#  ('샤넬', 2)]

# %%
plt.figure(figsize=(12,6))
gifts.plot(50) 
plt.show()

# %%
data = gifts.vocab().most_common(300)

wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(12,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
mask = np.array(Image.open('data/wc5.heart.jpg'))

from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(mask)

# %%
data = gifts.vocab().most_common(200)

wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
               relative_scaling = 0.1, mask=mask,
               background_color = 'white',
               min_font_size=1,
               max_font_size=100).generate_from_frequencies(dict(data))

default_colors = wordcloud.to_array()

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()
